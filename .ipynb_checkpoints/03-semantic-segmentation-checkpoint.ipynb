# %% [markdown]
# ## 03 Semantic Segmentation

# %%
import wget, sys, tarfile, warnings, os, cv2
import matplotlib.pyplot as plt
from pathlib import Path
from utils import *
import numpy as np

# %%
warnings.simplefilter('ignore') #May want to supress fastai/pytorch warnings

# %%
def get_mvtech_dataset(data_dir, dataset_name): 
    data_dir.mkdir(exist_ok=True)
    if not (data_dir/('%s.tar.xz'%dataset_name)).exists():
        wget.download('ftp://guest:GU.205dldo@ftp.softronics.ch/mvtec_anomaly_detection/%s.tar.xz'%dataset_name, \
                      out=str(data_dir/('%s.tar.xz'%dataset_name)), bar=simple_progress_bar)    
    if not (data_dir/dataset_name).exists():   
        tar=tarfile.open(data_dir/('%s.tar.xz'%dataset_name))
        tar.extractall(data_dir)
        tar.close()
        os.chmod(data_dir/dataset_name, 0o777) #May need to change permissionsdataset_name):

# %%
data_dir=Path('data/')
dataset_name='leather'
get_mvtech_dataset(data_dir, dataset_name=dataset_name)

# %%
list((data_dir/dataset_name).glob('*'))
# Out:
# [PosixPath('data/leather/test'),
#  PosixPath('data/leather/models'),
#  PosixPath('data/leather/test_good'),
#  PosixPath('data/leather/train'),
#  PosixPath('data/leather/readme.txt'),
#  PosixPath('data/leather/license.txt'),
#  PosixPath('data/leather/ground_truth')]

# %%
all_classes=[p.name for p in (data_dir/dataset_name/'test').glob('*')]

# %%
c=all_classes[0]
im_paths={int(p.name.split('.')[0]):p for p in (data_dir/dataset_name/'test'/c).glob('*')}
mask_paths={int(p.name.split('_')[0]):p for p in (data_dir/dataset_name/'ground_truth'/c).glob('*')}

# %%
i=1
im=cv2.cvtColor(cv2.imread(str(im_paths[i])), cv2.COLOR_BGR2RGB)
mask=cv2.imread(str(mask_paths[i]))

# %%
fig=plt.figure(0, (18,6))
fig.add_subplot(1,2,1); plt.imshow(im)
fig.add_subplot(1,2,2); plt.imshow(mask)

# %%
np.unique(mask)
# Out:
# array([  0, 255], dtype=uint8)

# %%
c=all_classes[0]
im_paths={int(p.name.split('.')[0]):p for p in (data_dir/dataset_name/'test'/c).glob('*')}
mask_paths={int(p.name.split('_')[0]):p for p in (data_dir/dataset_name/'ground_truth'/c).glob('*')}

# %%
mask_paths
# Out:
# {7: PosixPath('data/leather/ground_truth/color/007_mask.png'),
#  13: PosixPath('data/leather/ground_truth/color/013_mask.png'),
#  8: PosixPath('data/leather/ground_truth/color/008_mask.png'),
#  1: PosixPath('data/leather/ground_truth/color/001_mask.png'),
#  17: PosixPath('data/leather/ground_truth/color/017_mask.png'),
#  12: PosixPath('data/leather/ground_truth/color/012_mask.png'),
#  18: PosixPath('data/leather/ground_truth/color/018_mask.png'),
#  6: PosixPath('data/leather/ground_truth/color/006_mask.png'),
#  5: PosixPath('data/leather/ground_truth/color/005_mask.png'),
#  4: PosixPath('data/leather/ground_truth/color/004_mask.png'),
#  14: PosixPath('data/leather/ground_truth/color/014_mask.png'),
#  3: PosixPath('data/leather/ground_truth/color/003_mask.png'),
#  15: PosixPath('data/leather/ground_truth/color/015_mask.png'),
#  9: PosixPath('data/leather/ground_truth/color/009_mask.png'),
#  11: PosixPath('data/leather/ground_truth/color/011_mask.png'),
#  2: PosixPath('data/leather/ground_truth/color/002_mask.png'),
#  16: PosixPath('data/leather/ground_truth/color/016_mask.png'),
#  10: PosixPath('data/leather/ground_truth/color/010_mask.png'),
#  0: PosixPath('data/leather/ground_truth/color/000_mask.png')}

# %%
im_paths[0]
# Out:
# PosixPath('data/leather/test/color/000.png')

# %%
im_path=im_paths[0]

# %%
mask_path=data_dir/dataset_name/'ground_truth'/im_path.parent.name/(im_path.name.split('.')[0] + '_mask.' + im_path.name.split('.')[1])

# %%
# cv2.imread(str(mask_path))

# %%
def get_y_fn(x): return path/'masks'/(x.stem + '.png')

# %%
classes = array(['background', 'brick', 'ball', 'cylinder'])

# %%
src = (SegmentationItemList.from_folder(path/'images')
       .split_by_rand_pct(0.2)
       .label_from_func(get_y_fn, classes=classes))

# %%
data = (src.transform(get_transforms(), tfm_y=True, size=(256,256))
        .databunch(bs=16)
        .normalize(imagenet_stats))
